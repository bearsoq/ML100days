# %% [markdown]
# Day5-1 作業
#
# 在小量的資料上，我們用眼睛就可以看得出來程式碼是否有跑出我們理想中的結果。請嘗試想像一個你需要的資料結構 (裡面的值是隨機的)，然後用程式碼範例的方法把它變成 DataFrame
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
data = {'國家': ['Taiwan', 'United States', 'Thailand'],
        '人口': [3000000, 50000000, 7000000000]}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#               國家          人口
# 0         Taiwan     3000000
# 1  United States    50000000
# 2       Thailand  7000000000
